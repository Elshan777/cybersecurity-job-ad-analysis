# %%
import pandas as pd
import re
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from nltk.stem import WordNetLemmatizer 
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
import string
from wordcloud import WordCloud
from textblob import TextBlob
import seaborn as sns

# %%
df = pd.read_csv('../data/jobs.csv')
df.head()
# Out:
#   country      title                                               text
# 0      AT     Inform  https://www.linkedin.com/company/global-blue/l...
# 1      AT  Architect  https://www.linkedin.com/jobs/view/2589036509/...
# 2      AT    Manager  www.linkedin.com/jobs/view/2540581439/\n\nInfo...
# 3      AT    Analyst  https://www.linkedin.com/jobs/view/2997674064\...
# 4      AT   Engineer  https://www.linkedin.com/jobs/view/3020920801\...

# %%
# Removal of links
df['text'] = df['text'].apply(lambda x: re.sub(r'https?://\S+|www\.\S+', '', x))

# Extract Job Title from text
df['job_title'] = df['text'].apply(lambda x: (re.sub(r'^.*?\n', '\n', x).strip()).split('\n')[0] )


def remove_Stopwords(text ):
    stop_words = set(stopwords.words('english')) 
    words = word_tokenize( text.lower() ) 
    sentence = [w for w in words if not w in stop_words]
    return " ".join(sentence)
    

def lemmatize_text(text):
    wordlist=[]
    lemmatizer = WordNetLemmatizer() 
    sentences=sent_tokenize(text)
    for sentence in sentences:
        words=word_tokenize(sentence)
        for word in words:
            wordlist.append(lemmatizer.lemmatize(word))
    return ' '.join(wordlist) 

def clean_text(text ): 
    delete_dict = {sp_character: '' for sp_character in string.punctuation} 
    delete_dict[' '] = ' ' 
    table = str.maketrans(delete_dict)
    text1 = text.translate(table)
    textArr= text1.split()
    text2 = ' '.join([w for w in textArr]) 
    
    return text2.lower()

df['text'] = df['text'].apply(clean_text)
df['text'] = df['text'].apply(remove_Stopwords)
df['text'] = df['text'].apply(lemmatize_text)

df.head()
# Out:
#   country      title                                               text  \
# 0      AT     Inform  information technology security manager global...
# 1      AT  Architect  information security architect copmany swarovs...
# 2      AT    Manager  information technology security manager copman...
# 3      AT    Analyst  threat detection analyst company radar cyber s...
# 4      AT   Engineer  security engineer company global blue location...
#
#                                  job_title
# 0  Information Technology Security Manager
# 1           Information Security Architect
# 2  Information Technology Security Manager
# 3                 Threat Detection Analyst
# 4                     IT Security Engineer

# %%
wordcloud = WordCloud(background_color="white",width=1600, height=800).generate(' '.join(df['text'].tolist()))
plt.figure( figsize=(20,10), facecolor='k')
plt.imshow(wordcloud)

# %%
wordcloud = WordCloud(background_color="white",width=1600, height=800).generate(' '.join(df['job_title'].tolist()))
plt.figure( figsize=(20,10), facecolor='k')
plt.imshow(wordcloud)

# %% [markdown]
# ## Job Posting by countries

# %%
df['country'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# We have jobs from Czech Republic more than any other country

# %% [markdown]
# ### Wordmap by countries

# %%
cz_df = df[ df['country'] == 'CZ' ]
wordcloud = WordCloud(background_color="white",width=1600, height=800).generate(' '.join(cz_df['text'].tolist()))
plt.figure( figsize=(20,10), facecolor='k')
plt.imshow(wordcloud)

# %%
hu_df = df[ df['country'] == 'HU' ]
wordcloud = WordCloud(background_color="white",width=1600, height=800).generate(' '.join(hu_df['text'].tolist()))
plt.figure( figsize=(20,10), facecolor='k')
plt.imshow(wordcloud)

# %%
lt_df = df[ df['country'] == 'LT' ]
wordcloud = WordCloud(background_color="white",width=1600, height=800).generate(' '.join(lt_df['text'].tolist()))
plt.figure( figsize=(20,10), facecolor='k')
plt.imshow(wordcloud)

# %%
df['polarity'] = df['text'].map(lambda text: TextBlob(text).sentiment.polarity)
df['word_count'] = df['text'].apply(lambda x: len(str(x).split()))
df.head()
# Out:
#   country      title                                               text  \
# 0      AT     Inform  information technology security manager global...
# 1      AT  Architect  information security architect copmany swarovs...
# 2      AT    Manager  information technology security manager copman...
# 3      AT    Analyst  threat detection analyst company radar cyber s...
# 4      AT   Engineer  security engineer company global blue location...
#
#                                  job_title  polarity  word_count
# 0  Information Technology Security Manager  0.072107         732
# 1           Information Security Architect  0.122043         249
# 2  Information Technology Security Manager  0.115965         441
# 3                 Threat Detection Analyst  0.200856         189
# 4                     IT Security Engineer  0.165756         329

# %%
df[['polarity', 'word_count']].hist(bins=50, figsize=(15, 10))
# Out:
# array([[<AxesSubplot:title={'center':'polarity'}>,
#         <AxesSubplot:title={'center':'word_count'}>]], dtype=object)

# %%
plt.figure(figsize = (10, 8))
sns.set_style('whitegrid')
sns.set(font_scale = 1.5)
sns.boxplot(x = 'country', y = 'polarity', data = df)
plt.xlabel("Rating")
plt.ylabel("Polatiry")
plt.title("Product Ratings vs Polarity")
plt.show()

# %%
df[df['country'] == 'FR']['text'][53]
# Out:
# 'senior digital forensics consultant verizon paris ã\x8eledefrance france 2 hour ago 3 applicant fulltime â· midsenior level job youâ\x80\x99ll senior digital forensic ir investigator within company investigative response team youâ\x80\x99ll expected serve tactical arm team conducting live incident response computer forensic analysis data recovery investigative work due inherent volatility investigative response work candidate expected discharge various responsibility assigned role successfully managing variable case load role responsible integrity analysis quality client deliverable well gathering caseload intelligence position operate close team computer forensics fraud examiner investigative expert well customer management counsel human resource technical personnel role youâ\x80\x99ll responsible leading engagement least 2 core offering pcirelated irforensics investigation financial service intellectual property computer security incident response team csirt expert witnesslitigation support ir training industrial control system mobile phone forensics must able assist customer responding rapidly effectively computerrelated incident consistently exceed expectation working customerfacing setting capability quickly identify source security breach move toward containment youll need weâ\x80\x99re looking bachelor degree relevant work experience experience tool technique methodology surrounding incident response computer forensics industrial control system iot ediscovery experience following operating system unix linux window macos experience conducting security assessment penetration testing ethical hacking experience managing daytoday aspect protected customer relationship well investigative case corporate security incident willingness travel valid driver license fluency french written verbal even better one following advanced degree experience evidentiary procedure volatile criminalcivil situation fraud analysis ir fundamental understanding information security network architecture general database concept document management hardware software troubleshooting email system microsoft exchange office365 gsuite microsoft office application computer forensic tool encase ftk experience regarding malware analysis reverse engineering network forensics memory forensics mobile forensics ability work dynamic environment maintaining confidentiality professional image approach customer critical experience electronic crime law enforcement military intelligence security professional service organization experience security professional service consulting firm pci qsaqira gcfa certification ability successfully achieve one within first 6 month employment'
